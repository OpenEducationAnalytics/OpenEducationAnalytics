# %% [markdown]
# # Clever Test Data Generation Demonstration Notebook
#
# This OEA test data generation notebook illustrates use of the OEA_py, test_data_generation_py, and clever_test_data_generation_py python classes for creating and developing test data for the Clever module in Stage 1np.
#
# After executing the test_data_gen_demo notebook, this notebook uses the base-truth tables to generate artifical test data for the Clever module.
#
# Review and use the functions outlined in the clever_test_data_generation_py class notebook to create this test data. For example, if you wish to change the date range of the test data generated, update the ```startdate``` or ```enddate``` parameters.
#
# **NOTE:** The ```gen_daily_participation()``` function must be executed prior to executing ```gen_resource_usage()``` function, as the resource usage file is dependent on the data from the daily participation file.

# %%
# %run /OEA_py
# Out:
# StatementMeta(, 107, -1, Finished, Available)
# 2022-11-08 15:45:45,005 - OEA - DEBUG - OEA initialized.
# OEA initialized.

# %%
# %run /clever_test_data_generation_py
# Out:
# StatementMeta(, 107, -1, Finished, Available)

# %%
oea = OEA()
# Out:
# StatementMeta(sparkMed, 107, 3, Finished, Available)
# 2022-11-08 15:45:53,911 - OEA - DEBUG - OEA initialized.
# 2022-11-08 15:45:53,911 - OEA - DEBUG - OEA initialized.
# OEA initialized.

# %%
clever_datagen = CleverDataGen()
# Out:
# StatementMeta(sparkMed, 107, 76, Finished, Available)

# %%
clever_datagen.gen_daily_participation()
clever_datagen.gen_resource_usage()
# Out:
# StatementMeta(sparkMed, 107, 78, Finished, Available)
# <ipython-input-75-5a1d789f>:62: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ipython-input-75-5a1d789f>:62: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ipython-input-75-5a1d789f>:62: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ipython-input-75-5a1d789f>:62: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ipython-input-75-5a1d789f>:62: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# uncomment this line of code if you want to reset either or both generated Clever test data tables
#clever_datagen.reset_generation(reset_daily_participation=True, reset_resource_usage=True)
